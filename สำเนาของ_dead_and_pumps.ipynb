# %% [markdown]
# <a href="https://colab.research.google.com/github/pongsathornantari/53-1156-320-8/blob/master/%E0%B8%AA%E0%B8%B3%E0%B9%80%E0%B8%99%E0%B8%B2%E0%B8%82%E0%B8%AD%E0%B8%87_dead_and_pumps.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import seaborn as sns
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
pump = pd.read_csv("/content/drive/My Drive/Colab Notebooks/Snow.pumps.csv")
death = pd.read_csv("/content/drive/My Drive/Colab Notebooks/Snow.deaths2.csv")

# %%
fig = plt.figure()
fig.set_size_inches(18.5, 10.5)
ax1 = fig.add_subplot(121)
ax2 = fig.add_subplot(122)

# %%
pump
# Out:
#     Unnamed: 0  pump           label          x          y
# 0            1     1   Oxford Market   8.651201  17.891600
# 1            2     2     Castle St E  10.984780  18.517851
# 2            3     3    Oxford St #1  13.378190  17.394541
# 3            4     4    Oxford St #2  14.879830  17.809919
# 4            5     5  Gt Marlborough   8.694768  14.905470
# 5            6     6    Crown Chapel   8.864416  12.753540
# 6            7     7        Broad St  12.571360  11.727170
# 7            8     8         Warwick  10.660970   7.428647
# 8            9     9      Briddle St  13.521460   7.958250
# 9           10    10         So Soho  16.434891   9.252130
# 10          11    11         Dean St  18.914391   9.737819
# 11          12    12     Coventry St  16.005110   5.046838
# 12          13    13         Vigo St   8.999440   5.101023

# %%
death
# Out:
#      Unnamed: 0  case          x          y
# 0             1     1  13.588010  11.095600
# 1             2     2   9.878124  12.559180
# 2             3     3  14.653980  10.180440
# 3             4     4  15.220570   9.993003
# 4             5     5  13.162650  12.963190
# ..          ...   ...        ...        ...
# 573         574   574  12.438040  11.536670
# 574         575   575  15.050640  10.174120
# 575         576   576  17.271660  11.633800
# 576         577   577  12.426100  11.914420
# 577         578   578  15.018170  12.515810
#
# [578 rows x 4 columns]

# %%
ax2 = plt.scatter(death["x"], death["y"] , color="red")
ax1 = plt.scatter(pump["x"], pump["y"], pump["label"] color="blue")
# Out:
#   File "<ipython-input-2-4bfe114845ea>", line 2
#     ax1 = plt.scatter(pump["x"], pump["y"], pump["label"] color="blue")
#                                                               ^
# SyntaxError: invalid syntax

# %%
img = plt.imread("/content/drive/My Drive/Colab Notebooks/metro.PNG")
#print(img)
plt.imshow(img, aspect='auto')
#ax2 = plt.scatter(death["x"], death["y"], color="red")
#ax1 = plt.scatter(pump["x"], pump["y"], color="blue")
#plt.savefig("/content/drive/My Drive/Colab Notebooks/lena_color_mod.png",bbox_inches="tight",pad_inches=0.02,dpi=250)

# %%
from PIL import Image
img = plt.imread("/content/drive/My Drive/Colab Notebooks/metro.PNG")
fig, ax = plt.subplots()
ax.imshow(img)
